# %%
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('max_colwidth', None)

# %%
df1 = pd.read_csv('./hcm_famous_place.csv')
df2 = pd.read_csv('./hn_famous_place.csv')

# df1 = df1.dropna()
# df2 = df2.dropna()
# pd.concat([df1, df2], axis = 0).sample(frac = 1.0).head(20)

# %%
df2
# Out:
#           lat         lon                                           name  \
# 0   20.995879  105.866136                              Vincom Times City
# 1   21.031896  105.809439                             Lotte Center Hanoi
# 2   20.989709  105.749142                              Aeon Mall Hà Đông
# 3   21.002143  105.812609         Trung tâm thương mại Royal City Hà Nội
# 4   21.035747  105.780272               Indochina Plaza Hanoi Residences
# 5   21.044656  105.842660       Trung tâm thương mại Hà Nội Aqua Central
# 6   21.003251  105.801975       Trung tâm thương mại Hà Nội Center Point
# 7   21.024366  105.851294  Trung tâm thương mại Hà Nội Tràng Tiền Plaza
# 8   21.016627  105.782185           Trung tâm thương mại Hà Nội Keangnam
# 9   21.027274  105.896800                            Aeon Mall Long Biên
# 10  21.011068  105.846908                                Vincom Bà Triệu
# 11  21.007419  105.790613                                 GO! Thăng Long
# ...
